# %%
import requests
import pandas as pd
import os
from datetime import datetime, timedelta

# Gravar chave de API da NASA
api_key = 'lSiHUoZHOfiBYwa5vgVXmTgSeRSvhEWq6TGapANg'


def obter_dados_api(url):
    # Fazendo a solicitação GET para a API
    response = requests.get(url)

    # Verificando se a solicitação foi bem-sucedida
    if response.status_code == 200:
        # Convertendo a resposta para formato JSON
        data = response.json()
        # Retornando os dados
        return data
    else:
        print("Erro ao acessar a API")

# Função para gerar as datas do mês atual até D-2
def gerar_datas_mes_corrente():
    hoje = datetime.now()
    data_final = hoje - timedelta(days=2)
    data_inicial = hoje.replace(day=1)
    datas = []
    while data_inicial <= data_final:
        datas.append(data_inicial.strftime('%Y-%m-%d'))
        data_inicial += timedelta(days=1)
    return datas

# Gerar as datas desejadas
datas_para_busca = gerar_datas_mes_corrente()

# Inicializando uma lista para armazenar os dados do rover
photo_data = []

#pra cada data coletar os dados do rover
for data in datas_para_busca:
    url = f"https://api.nasa.gov/mars-photos/api/v1/rovers/Perseverance/photos?earth_date={data}&api_key={api_key}"
    print(f"Buscando dados para a data: {data}")
    dados = obter_dados_api(url)
    
    if dados and 'photos' in dados:
        for photo in dados['photos']:
            photo_data.append({
                'photo_id': photo['id'],
                'sol': photo['sol'],
                'camera_id': photo['camera']['id'],
                'camera_name': photo['camera']['name'],
                'camera_full_name': photo['camera']['full_name'],
                'img_src': photo['img_src'],
                'earth_date': photo['earth_date'],
                'rover_id': photo['rover']['id'],
                'rover_name': photo['rover']['name'],
                'rover_landing_date': photo['rover']['landing_date'],
                'rover_launch_date': photo['rover']['launch_date'],
                'rover_status': photo['rover']['status'],
            })



# Criando o DataFrame a partir da lista de dicionários
df = pd.DataFrame(photo_data)

# Exibindo o DataFrame
df
# Out:
# Buscando dados para a data: 2024-10-01
# Buscando dados para a data: 2024-10-02
# Buscando dados para a data: 2024-10-03
# Buscando dados para a data: 2024-10-04
# Buscando dados para a data: 2024-10-05
# Buscando dados para a data: 2024-10-06
# Buscando dados para a data: 2024-10-07
# Buscando dados para a data: 2024-10-08
# Buscando dados para a data: 2024-10-09
# Buscando dados para a data: 2024-10-10
# Buscando dados para a data: 2024-10-11
# Buscando dados para a data: 2024-10-12
# Buscando dados para a data: 2024-10-13
# Buscando dados para a data: 2024-10-14
# Buscando dados para a data: 2024-10-15
# Buscando dados para a data: 2024-10-16
# Buscando dados para a data: 2024-10-17
# Buscando dados para a data: 2024-10-18
# Buscando dados para a data: 2024-10-19
# Buscando dados para a data: 2024-10-20
# Buscando dados para a data: 2024-10-21
# Buscando dados para a data: 2024-10-22
# Buscando dados para a data: 2024-10-23
# Buscando dados para a data: 2024-10-24
# Buscando dados para a data: 2024-10-25
# Buscando dados para a data: 2024-10-26
# Buscando dados para a data: 2024-10-27
# Buscando dados para a data: 2024-10-28
# Buscando dados para a data: 2024-10-29
#       photo_id   sol  camera_id   camera_name              camera_full_name  \
# 0      1269523  1286         38   NAVCAM_LEFT      Navigation Camera - Left
# 1      1269534  1286         38   NAVCAM_LEFT      Navigation Camera - Left
# 2      1269535  1286         38   NAVCAM_LEFT      Navigation Camera - Left
# 3      1269549  1286         38   NAVCAM_LEFT      Navigation Camera - Left
# 4      1269550  1286         38   NAVCAM_LEFT      Navigation Camera - Left
# ...        ...   ...        ...           ...                           ...
# 5509   1275243  1313         48  SUPERCAM_RMI  SuperCam Remote Micro Imager
# 5510   1275244  1313         48  SUPERCAM_RMI  SuperCam Remote Micro Imager
# 5511   1275245  1313         48  SUPERCAM_RMI  SuperCam Remote Micro Imager
# 5512   1275246  1313         48  SUPERCAM_RMI  SuperCam Remote Micro Imager
# 5513   1275269  1313         48  SUPERCAM_RMI  SuperCam Remote Micro Imager
#
#                                                 img_src  earth_date  rover_id  \
# 0     https://mars.nasa.gov/mars2020-raw-images/pub/...  2024-10-01         8
# 1     https://mars.nasa.gov/mars2020-raw-images/pub/...  2024-10-01         8
# 2     https://mars.nasa.gov/mars2020-raw-images/pub/...  2024-10-01         8
# 3     https://mars.nasa.gov/mars2020-raw-images/pub/...  2024-10-01         8
# 4     https://mars.nasa.gov/mars2020-raw-images/pub/...  2024-10-01         8
# ...                                                 ...         ...       ...
# 5509  https://mars.nasa.gov/mars2020-raw-images/pub/...  2024-10-29         8
# 5510  https://mars.nasa.gov/mars2020-raw-images/pub/...  2024-10-29         8
# 5511  https://mars.nasa.gov/mars2020-raw-images/pub/...  2024-10-29         8
# 5512  https://mars.nasa.gov/mars2020-raw-images/pub/...  2024-10-29         8
# 5513  https://mars.nasa.gov/mars2020-raw-images/pub/...  2024-10-29         8
#
#         rover_name rover_landing_date rover_launch_date rover_status
# 0     Perseverance         2021-02-18        2020-07-30       active
# 1     Perseverance         2021-02-18        2020-07-30       active
# 2     Perseverance         2021-02-18        2020-07-30       active
# 3     Perseverance         2021-02-18        2020-07-30       active
# 4     Perseverance         2021-02-18        2020-07-30       active
# ...            ...                ...               ...          ...
# 5509  Perseverance         2021-02-18        2020-07-30       active
# 5510  Perseverance         2021-02-18        2020-07-30       active
# 5511  Perseverance         2021-02-18        2020-07-30       active
# 5512  Perseverance         2021-02-18        2020-07-30       active
# 5513  Perseverance         2021-02-18        2020-07-30       active
#
# [5514 rows x 12 columns]

# %%
# Salvar o DataFrame em formato CSV
df.to_csv('Perseverance.csv', index=False)

# %%
# Criar o diretório principal com o nome do rover
if photo_data:
    rover_name = photo_data[0]['rover_name']
    directory = rover_name
    print(f"criando o diretorio {directory}")
    os.makedirs(directory, exist_ok=True)

    # Baixar cada uma das fotos e salvar no diretório organizado por data
    for photo in photo_data:
        data_pasta = photo['earth_date']
        data_directory = os.path.join(directory, data_pasta)
        os.makedirs(data_directory, exist_ok=True)
        print(f"criando o diretorio {data_directory}")

        img_url = photo['img_src']
        img_name = os.path.join(data_directory, f"{photo['photo_id']}.jpg")
        response = requests.get(img_url)
        if response.status_code == 200:
            with open(img_name, 'wb') as img_file:
                img_file.write(response.content)
                print(f"coletei a imagem {img_name}")
        else:
            print(f"Erro ao baixar a imagem {photo['photo_id']} da data {data_pasta}")
# Out:
# criando o diretorio Perseverance
# criando o diretorio Perseverance\2024-10-01
# coletei a imagem Perseverance\2024-10-01\1